# %% [markdown]
# # Incoherent VS. coherent PSF

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fftpack import fft2,ifft2,fftshift,ifftshift
from scipy.signal import fftconvolve as conv
from scipy.special import j1

# %%
obj = plt.imread('sample.jpg')
plt.imshow(obj)
plt.show()

# %%
xy = np.linspace(-10,10,obj.shape[0])
x,y = np.meshgrid(xy,xy)
r = np.sqrt(x**2+y**2)

def jinc(r):
    return

# %%
im_coherent = np.abs(conv(obj,PSF_))
